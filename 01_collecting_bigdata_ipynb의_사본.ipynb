# %% [markdown]
# <a href="https://colab.research.google.com/github/Jihoon135224/medicalData/blob/main/01_collecting_bigdata_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HTTP Request를 활용한 데이터 수집

# %%
import requests, sys

# 요청 url 설정
server_url = "https://rest.ensembl.org"
ext_url = "/overlap/id/ENSG00000157764?feature=gene"

# HTTP GET method 호출
r = requests.get(server_url + ext_url, headers={ "Content-Type" : "application/json"})

# 예외 처리
if not r.ok:
  r.raise_for_status()
  sys.exit()

# Response 확인
decoded = r.json()
print(repr(decoded))
# Out:
# [{'description': 'NADH:ubiquinone oxidoreductase subunit B2 [Source:HGNC Symbol;Acc:HGNC:7697]', 'external_name': 'NDUFB2', 'gene_id': 'ENSG00000090266', 'strand': 1, 'version': 13, 'id': 'ENSG00000090266', 'seq_region_name': '7', 'canonical_transcript': 'ENST00000247866.9', 'feature_type': 'gene', 'end': 140722790, 'biotype': 'protein_coding', 'start': 140690777, 'source': 'ensembl_havana', 'assembly_name': 'GRCh38', 'logic_name': 'ensembl_havana_gene_homo_sapiens'}, {'id': 'ENSG00000271932', 'canonical_transcript': 'ENST00000605989.1', 'feature_type': 'gene', 'seq_region_name': '7', 'start': 140884072, 'source': 'ensembl', 'biotype': 'snRNA', 'end': 140884178, 'logic_name': 'ncrna_homo_sapiens', 'assembly_name': 'GRCh38', 'description': 'RNA, U6 small nuclear 85, pseudogene [Source:HGNC Symbol;Acc:HGNC:47048]', 'external_name': 'RNU6-85P', 'strand': 1, 'gene_id': 'ENSG00000271932', 'version': 1}, {'logic_name': 'havana_homo_sapiens', 'assembly_name': 'GRCh38', 'start': 140767530, '
# ...

# %%
# 데이터 프레임 형태로 저장 및 출력
import pandas as pd
df = pd.DataFrame(decoded)
df
# Out:
#                                          description external_name  \
# 0  NADH:ubiquinone oxidoreductase subunit B2 [Sou...        NDUFB2
# 1  RNA, U6 small nuclear 85, pseudogene [Source:H...      RNU6-85P
# 2                 novel transcript antisense to BRAF           NaN
# 3  B-Raf proto-oncogene, serine/threonine kinase ...          BRAF
#
#            gene_id  strand  version               id seq_region_name  \
# 0  ENSG00000090266       1       13  ENSG00000090266               7
# 1  ENSG00000271932       1        1  ENSG00000271932               7
# 2  ENSG00000289788       1        1  ENSG00000289788               7
# 3  ENSG00000157764      -1       14  ENSG00000157764               7
#
#   canonical_transcript feature_type        end         biotype      start  \
# 0    ENST00000247866.9         gene  140722790  protein_coding  140690777
# 1    ENST00000605989.1         gene  140884178           snRNA  140884072
# ...

# %% [markdown]
# # BeautifulSoup를 활용한 크롤링

# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
# target url
url = "https://www.naver.com"

# 웹페이지 호출
response = requests.get(url, timeout=5)
soup = BeautifulSoup(response.content, "html.parser")

# 확인
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-be0bd59b53d3> in <cell line: 0>()
#       3
#       4 # 웹페이지 호출
# ----> 5 response = requests.get(url, timeout=5)
#       6 soup = BeautifulSoup(response.content, "html.parser")
#       7
#
# NameError: name 'requests' is not defined
